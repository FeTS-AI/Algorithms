# %%
# import supporting code
from inspect_federation_module import parse_logs, plot_convergence_curve

# %%
parent_dir = '/home/edwardsb/repositories/be-OpenFederatedLearning/bin'

# %%
specific_directory_nofix = 'logs_5' # (NO NORMALIZATION)

# %%
# Parse the aggregator logs from the running federation to get the training progress
round_nums, validation_scores = parse_logs(specific_directory=specific_directory_nofix, parent_dir=parent_dir)
# Out:
# Parsing:  logs_5/aggregator.log
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-73-0191de3b8218> in <module>
#       1 # Parse the aggregator logs from the running federation to get the training progress
# ----> 2 round_nums, validation_scores = parse_logs(specific_directory=specific_directory_nofix, parent_dir=parent_dir)
#
# ~/repositories/be-Algorithms/fets/bin/plot_fed_training_curves/inspect_federation_module.py in parse_logs(running, specific_directory, faster, parent_dir, info)
#     149         if faster:
#     150             if info=='val':
# --> 151                 temp_round_nums, temp_scores = faster_get_arrays_from_file(fpath)
#     152             elif info=='loss':
#     153                 temp_round_nums, temp_scores = faster_get_arrays_from_file(fpath, line_shift=1, sanity_check_token_idx=None)
#
# ...

# %%
# plot the global model training progress
plot_convergence_curve(round_nums, validation_scores)

# %%
# Parse the aggregator logs from the running federation to get the training progress
round_nums, losses = parse_logs(specific_directory=specific_directory_nofix, parent_dir=parent_dir, info='loss')
# Out:
# Parsing:  logs_5/aggregator.log

# %%
# plot the global model training progress
plot_convergence_curve(round_nums, losses, info='loss')

# %%
specific_directory_nofix = 'logs_6' # (NO NORMALIZATION)

# %%
# Parse the aggregator logs from the running federation to get the training progress
round_nums, validation_scores = parse_logs(specific_directory=specific_directory_nofix, parent_dir=parent_dir)
# Out:
# Parsing:  logs_6/aggregator.log

# %%
# plot the global model training progress
plot_convergence_curve(round_nums, validation_scores)

# %%
# Parse the aggregator logs from the running federation to get the training progress
round_nums, losses = parse_logs(specific_directory=specific_directory_nofix, parent_dir=parent_dir, info='loss')
# Out:
# Parsing:  logs_6/aggregator.log

# %%
# plot the global model training progress
plot_convergence_curve(round_nums, losses, info='loss')

# %%
specific_directory_nofix = 'logs_7' # FIXED NORMALIZATION

# %%
# Parse the aggregator logs from the running federation to get the training progress
round_nums, validation_scores = parse_logs(specific_directory=specific_directory_nofix, parent_dir=parent_dir)
# Out:
# Parsing:  logs_7/aggregator.log

# %%
# plot the global model training progress
plot_convergence_curve(round_nums, validation_scores)

# %%
# Parse the aggregator logs from the running federation to get the training progress
round_nums, losses = parse_logs(specific_directory=specific_directory_nofix, parent_dir=parent_dir, info='loss')
# Out:
# Parsing:  logs_7/aggregator.log

# %%
# plot the global model training progress
plot_convergence_curve(round_nums, losses, info='loss')

# %%
specific_directory_nofix = 'logs_8' # FIXED NORMALIZATION

# %%
# Parse the aggregator logs from the running federation to get the training progress
round_nums, validation_scores = parse_logs(specific_directory=specific_directory_nofix, parent_dir=parent_dir)
# Out:
# Parsing:  logs_8/aggregator.log

# %%
# plot the global model training progress
plot_convergence_curve(round_nums, validation_scores)

# %%
# Parse the aggregator logs from the running federation to get the training progress
round_nums, losses = parse_logs(specific_directory=specific_directory_nofix, parent_dir=parent_dir, info='loss')
# Out:
# Parsing:  logs_8/aggregator.log

# %%
# plot the global model training progress
plot_convergence_curve(round_nums, losses, info='loss')
